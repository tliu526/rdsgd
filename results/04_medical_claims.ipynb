# %% [markdown]
# # Description

# %% [markdown]
# Notebook for generating medical claims figures and results (Section 6).

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pickle
import seaborn as sns
import sys

from scipy.stats import ttest_ind_from_stats
from tqdm import tqdm

# %%
# notebook magics
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
sys.path.append("../src/rdd-discovery/utils/")

# %% [markdown]
# # Load data

# %%
clinic_settings = ['breast_cancer', 'colon_cancer', 'diabetes']
clinic_dict = {}
data_dir = "../data/{}_running.parq"

for clinic in clinic_settings:
    df = pd.read_parquet(data_dir.format(clinic))
    clinic_dict[clinic] = df

# %% [markdown]
# # Point plot figure

# %%
blue = sns.color_palette()[0]
orange = sns.color_palette()[1]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(8,2.75), dpi=300, gridspec_kw = {'wspace':0.25, 'hspace':0})

point_plot_kwargs = dict(
    join=False,
    n_boot=50, 
    ci=95, 
    scale=0.5,
    errwidth=1, 
    capsize=0.2,
)


# breast cancer
bc_df = clinic_dict['breast_cancer']
#print(bc_df.columns)
ax1.axvline(x=3, ls='--', color='red', label="treatment cutoff", alpha=0.7)
ax1.set_title("Breast cancer screening")
sns.pointplot(data=bc_df, x='age', y='indicator', ax=ax1, color=blue, alpha=0.2, **point_plot_kwargs)
sns.pointplot(data=bc_df[bc_df['in_subgroup'] == 1], x='age', y='indicator', ax=ax1, color=orange, **point_plot_kwargs)
ax1.set_ylabel("treatment indicator")

# colon cancer
cc_df = clinic_dict['colon_cancer']

baseline_df = cc_df.copy()
baseline_df[" "] = 'baseline'
subgroup_df = cc_df[cc_df['in_subgroup'] == 1].copy()
subgroup_df[" "] = 'subgroup'
merge_df = baseline_df.append(subgroup_df)
#print(bc_df.columns)
ax2.axvline(x=3, ls='--', color='red', label="treatment cutoff", alpha=0.7)
ax2.set_title("Colon cancer screening")
#sns.pointplot(data=merge_df, x='age', y='indicator', ax=ax2, hue=" ", alpha=0.2, label="baseline", **point_plot_kwargs)
sns.pointplot(data=cc_df, x='age', y='indicator', ax=ax2, color=blue, alpha=0.2, label="baseline", **point_plot_kwargs)
sns.pointplot(data=cc_df[cc_df['in_subgroup'] == 1], x='age', y='indicator', ax=ax2, color=orange, label="RDSGD", **point_plot_kwargs)
ax2.set_ylabel("")

# diabetes
dm_df = clinic_dict['diabetes']
dm_df['lr_fmt'] = dm_df['lr_fmt'].round(1)

baseline_df = dm_df.copy()
baseline_df[" "] = 'baseline'
subgroup_df = dm_df[dm_df['in_subgroup'] == 1].copy()
subgroup_df[" "] = 'RDSGD'
merge_df = baseline_df.append(subgroup_df)

#print(bc_df.columns)
ax3.axvline(x=3, ls='--', color='red', label="cutoff", alpha=0.7)
ax3.set_title("Diabetes diagnosis")
sns.pointplot(data=merge_df, x='lr_fmt', y='indicator', ax=ax3, hue=" ", alpha=0.2, label="baseline", **point_plot_kwargs)
#sns.pointplot(data=dm_df, x='lr_fmt', y='indicator', ax=ax3, color=blue, alpha=0.2, **point_plot_kwargs)
#sns.pointplot(data=dm_df[dm_df['in_subgroup'] == 1], x='lr_fmt', y='indicator', ax=ax3, color=orange, **point_plot_kwargs)
#ax3.set_xlim(0.5, 7.5);
ax3.set_ylim(0.1, 0.7);
ax3.set_xlabel("A1C %");
ax3.legend(loc='upper left', labelspacing = 0)
ax3.set_ylabel("")
#ax3.set_ylabel("treatment indicator");

ax1.set_xticklabels(np.round(np.arange(37, 44, 1), 0))
ax2.set_xticklabels(np.round(np.arange(47, 54, 1), 0))
#ax3.set_xticklabels(np.round(np.arange(6.2, 6.9, 0.1), 1))

ax1.set_yticks([0.0, 0.1, 0.2])
ax2.set_yticks([0.0, 0.1, 0.2])
ax3.set_yticks([0.0, 0.4, 0.8])


fig.tight_layout()
plt.savefig("../figures/point_plot_split_sample.png", bbox_inches="tight")
# Out:
# /home/tliu/.conda/envs/rdd/lib/python3.7/site-packages/ipykernel_launcher.py:70: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# # T-tests for TAU differences

# %% [markdown]
# **TODO**: confirm that the claims_subgroups.dict file is generated.

# %% [markdown]
# ## Load data

# %%
# note, original data from llr_results were removed to fit within file size limit
subgroups_dict = pickle.load(open("../data/claims_subgroups.dict", "rb"))

# %%
for med_setting, med_dict in subgroups_dict.items():
    for key, d in med_dict.items(): 
        print(f"{med_setting}: {key}")
        print(d['llr_results'])
# Out:
# breast_cancer: baseline
#                             OLS Estimation Summary
# ==============================================================================
# Dep. Variable:              indicator   R-squared:                      0.0138
# Estimator:                        OLS   Adj. R-squared:                 0.0138
# No. Observations:              657881   F-statistic:                 1.073e+04
# Date:                Thu, Apr 14 2022   P-value (F-stat)                0.0000
# Time:                        15:05:13   Distribution:                  chi2(3)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.0179     0.0006     29.255     0.0000      0.0167      0.0191
# x_lower        0.0018     0.0003     6.4433     0.0000      0.0012      0.0023
# x_upper        0.0039     0.0003     11.545     0.0000      0.0033      0.0046
# z              0.0370     0.0009     42.945     0.0000      0.0353      0.0387
# ==============================================================================
# breast_cancer: subgroup
#                             OLS Estimation Summary
# ==============================================================================
# Dep. Variable:              indicator   R-squared:                      0.0387
# Estimator:                        OLS   Adj. R-squared:                 0.0386
# No. Observations:              306644   F-statistic:                 1.309e+04
# Date:                Thu, Apr 14 2022   P-value (F-stat)                0.0000
# Time:                        15:05:16   Distribution:                  chi2(3)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.0360     0.0012     29.496     0.0000      0.0336      0.0384
# x_lower        0.0037     0.0005     6.7041     0.0000      0.0026      0.0047
# x_upper        0.0143     0.0007     19.457     0.0000      0.0129      0.0157
# z              0.0810     0.0018     46.062     0.0000      0.0775      0.0844
# ==============================================================================
# colon_cancer: baseline
#                             OLS Estimation Summary
# ==============================================================================
# Dep. Variable:              indicator   R-squared:                      0.0166
# Estimator:                        OLS   Adj. R-squared:                 0.0166
# No. Observations:              692314   F-statistic:                 1.359e+04
# Date:                Wed, Apr 13 2022   P-value (F-stat)                0.0000
# Time:                        12:48:06   Distribution:                  chi2(3)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.0254     0.0007     34.721     0.0000      0.0239      0.0268
# x_lower        0.0016     0.0003     4.9417     0.0000      0.0010      0.0023
# x_upper       -0.0016     0.0004    -4.2234     0.0000     -0.0023     -0.0009
# z              0.0587     0.0010     57.789     0.0000      0.0567      0.0607
# ==============================================================================
# colon_cancer: subgroup
#                             OLS Estimation Summary
# ==============================================================================
# Dep. Variable:              indicator   R-squared:                      0.0453
# Estimator:                        OLS   Adj. R-squared:                 0.0453
# No. Observations:              197749   F-statistic:                 1.113e+04
# Date:                Wed, Apr 13 2022   P-value (F-stat)                0.0000
# Time:                        12:48:12   Distribution:                  chi2(3)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.0301     0.0015     20.176     0.0000      0.0272      0.0331
# x_lower        0.0025     0.0007     3.6863     0.0002      0.0012      0.0038
# x_upper       -0.0074     0.0009    -8.0684     0.0000     -0.0092     -0.0056
# z              0.1319     0.0023     56.957     0.0000      0.1274      0.1364
# ==============================================================================
# diabetes: baseline
#                             OLS Estimation Summary
# ==============================================================================
# Dep. Variable:              indicator   R-squared:                      0.0862
# Estimator:                        OLS   Adj. R-squared:                 0.0862
# No. Observations:              458077   F-statistic:                 4.142e+04
# Date:                Mon, Apr 11 2022   P-value (F-stat)                0.0000
# Time:                        17:36:13   Distribution:                  chi2(3)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.3590     0.0024     149.09     0.0000      0.3543      0.3638
# x_lower        0.5574     0.0100     55.859     0.0000      0.5378      0.5769
# x_upper        0.4771     0.0111     43.090     0.0000      0.4554      0.4988
# z              0.0898     0.0030     29.597     0.0000      0.0839      0.0958
# ==============================================================================
# diabetes: subgroup
#                             OLS Estimation Summary
# ==============================================================================
# Dep. Variable:              indicator   R-squared:                      0.1022
# Estimator:                        OLS   Adj. R-squared:                 0.1022
# No. Observations:              364609   F-statistic:                 3.818e+04
# Date:                Mon, Apr 11 2022   P-value (F-stat)                0.0000
# Time:                        17:36:15   Distribution:                  chi2(3)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.3182     0.0026     123.94     0.0000      0.3132      0.3233
# x_lower        0.5350     0.0105     50.808     0.0000      0.5143      0.5556
# x_upper        0.4956     0.0127     39.080     0.0000      0.4708      0.5205
# z              0.1139     0.0033     34.400     0.0000      0.1074      0.1204
# ==============================================================================

# %%
dm_bl = subgroups_dict['diabetes']['baseline']['llr_results']
dm_sub = subgroups_dict['diabetes']['subgroup']['llr_results']

# %%
cc_bl = subgroups_dict['colon_cancer']['baseline']['llr_results']
cc_sub = subgroups_dict['colon_cancer']['subgroup']['llr_results']

# %%
bc_bl = subgroups_dict['breast_cancer']['baseline']['llr_results']
bc_sub = subgroups_dict['breast_cancer']['subgroup']['llr_results']

# %%
ttest_ind_from_stats(dm_sub.params['z'], dm_sub.std_errors['z'], dm_sub.nobs,
                     dm_bl.params['z'], dm_bl.std_errors['z'], dm_bl.nobs,
                     equal_var=False)
# Out:
# Ttest_indResult(statistic=3394.497009222335, pvalue=0.0)

# %%
ttest_ind_from_stats(cc_sub.params['z'], cc_sub.std_errors['z'], cc_sub.nobs,
                     cc_bl.params['z'], cc_bl.std_errors['z'], cc_bl.nobs,
                     equal_var=False)
# Out:
# Ttest_indResult(statistic=13687.461941139063, pvalue=0.0)

# %%
ttest_ind_from_stats(bc_sub.params['z'], bc_sub.std_errors['z'], bc_sub.nobs,
                     bc_bl.params['z'], bc_bl.std_errors['z'], bc_bl.nobs,
                     equal_var=False)
# Out:
# Ttest_indResult(statistic=13125.751502916351, pvalue=0.0)
