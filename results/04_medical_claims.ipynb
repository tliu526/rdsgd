# %% [markdown]
# # Description

# %% [markdown]
# Notebook for generating medical claims figures and results (Section 6).

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pickle
import seaborn as sns
import sys

from scipy.stats import ttest_ind_from_stats
from tqdm import tqdm

# %%
# notebook magics
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
sys.path.append("../src/rdd-discovery/utils/")

# %% [markdown]
# # Load data

# %%
clinic_settings = ['breast_cancer', 'colon_cancer', 'diabetes']
clinic_dict = {}
data_dir = "../data/{}_running.parq"

for clinic in clinic_settings:
    df = pd.read_parquet(data_dir.format(clinic))
    clinic_dict[clinic] = df

# %% [markdown]
# # Point plot figure

# %%
blue = sns.color_palette()[0]
orange = sns.color_palette()[1]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(8,2.75), dpi=300, gridspec_kw = {'wspace':0.25, 'hspace':0})

point_plot_kwargs = dict(
    join=False,
    n_boot=50, 
    ci=95, 
    scale=0.5,
    errwidth=1, 
    capsize=0.2,
)


# breast cancer
bc_df = clinic_dict['breast_cancer']
#print(bc_df.columns)
ax1.axvline(x=3, ls='--', color='red', label="treatment cutoff", alpha=0.7)
ax1.set_title("Breast cancer screening")
sns.pointplot(data=bc_df, x='age', y='indicator', ax=ax1, color=blue, alpha=0.2, **point_plot_kwargs)
sns.pointplot(data=bc_df[bc_df['in_subgroup'] == 1], x='age', y='indicator', ax=ax1, color=orange, **point_plot_kwargs)
ax1.set_ylabel("treatment indicator")

# colon cancer
cc_df = clinic_dict['colon_cancer']

baseline_df = cc_df.copy()
baseline_df[" "] = 'baseline'
subgroup_df = cc_df[cc_df['in_subgroup'] == 1].copy()
subgroup_df[" "] = 'subgroup'
merge_df = baseline_df.append(subgroup_df)
#print(bc_df.columns)
ax2.axvline(x=3, ls='--', color='red', label="treatment cutoff", alpha=0.7)
ax2.set_title("Colon cancer screening")
#sns.pointplot(data=merge_df, x='age', y='indicator', ax=ax2, hue=" ", alpha=0.2, label="baseline", **point_plot_kwargs)
sns.pointplot(data=cc_df, x='age', y='indicator', ax=ax2, color=blue, alpha=0.2, label="baseline", **point_plot_kwargs)
sns.pointplot(data=cc_df[cc_df['in_subgroup'] == 1], x='age', y='indicator', ax=ax2, color=orange, label="RDSGD", **point_plot_kwargs)
ax2.set_ylabel("")

# diabetes
dm_df = clinic_dict['diabetes']
dm_df['lr_fmt'] = dm_df['lr_fmt'].round(1)

baseline_df = dm_df.copy()
baseline_df[" "] = 'baseline'
subgroup_df = dm_df[dm_df['in_subgroup'] == 1].copy()
subgroup_df[" "] = 'RDSGD'
merge_df = baseline_df.append(subgroup_df)

#print(bc_df.columns)
ax3.axvline(x=3, ls='--', color='red', label="cutoff", alpha=0.7)
ax3.set_title("Diabetes diagnosis")
sns.pointplot(data=merge_df, x='lr_fmt', y='indicator', ax=ax3, hue=" ", alpha=0.2, label="baseline", **point_plot_kwargs)
#sns.pointplot(data=dm_df, x='lr_fmt', y='indicator', ax=ax3, color=blue, alpha=0.2, **point_plot_kwargs)
#sns.pointplot(data=dm_df[dm_df['in_subgroup'] == 1], x='lr_fmt', y='indicator', ax=ax3, color=orange, **point_plot_kwargs)
#ax3.set_xlim(0.5, 7.5);
ax3.set_ylim(0.1, 0.7);
ax3.set_xlabel("A1C %");
ax3.legend(loc='upper left', labelspacing = 0)
ax3.set_ylabel("")
#ax3.set_ylabel("treatment indicator");

ax1.set_xticklabels(np.round(np.arange(37, 44, 1), 0))
ax2.set_xticklabels(np.round(np.arange(47, 54, 1), 0))
#ax3.set_xticklabels(np.round(np.arange(6.2, 6.9, 0.1), 1))

ax1.set_yticks([0.0, 0.1, 0.2])
ax2.set_yticks([0.0, 0.1, 0.2])
ax3.set_yticks([0.0, 0.4, 0.8])


fig.tight_layout()
plt.savefig("../figures/point_plot_split_sample.png", bbox_inches="tight")
# Out:
# /tmp/ipykernel_3802765/2358175560.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merge_df = baseline_df.append(subgroup_df)
# /tmp/ipykernel_3802765/2358175560.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merge_df = baseline_df.append(subgroup_df)
# /tmp/ipykernel_3802765/2358175560.py:70: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# # T-tests for TAU differences

# %% [markdown]
# ## Load data

# %%
subgroups_dict = pickle.load(open("../data/claims_subgroups.dict", "rb"))

# %%
for med_setting, med_dict in subgroups_dict.items():
    for key, d in med_dict.items(): 
        print(f"{med_setting}: {key}")
        print(d['llr_results'])
# Out:
# breast_cancer: subgroup
#                             OLS Estimation Summary
# ==============================================================================
# Dep. Variable:              indicator   R-squared:                      0.0421
# Estimator:                        OLS   Adj. R-squared:                 0.0421
# No. Observations:              146175   F-statistic:                    6878.3
# Date:                Mon, Aug 28 2023   P-value (F-stat)                0.0000
# Time:                        15:15:26   Distribution:                  chi2(3)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.0360     0.0018     20.488     0.0000      0.0326      0.0394
# x_lower        0.0038     0.0008     4.8969     0.0000      0.0023      0.0054
# x_upper        0.0144     0.0011     13.291     0.0000      0.0123      0.0165
# z              0.0875     0.0026     34.095     0.0000      0.0825      0.0925
# ==============================================================================
# breast_cancer: baseline
#                             OLS Estimation Summary
# ==============================================================================
# Dep. Variable:              indicator   R-squared:                      0.0148
# Estimator:                        OLS   Adj. R-squared:                 0.0148
# No. Observations:              315225   F-statistic:                    5606.5
# Date:                Mon, Aug 28 2023   P-value (F-stat)                0.0000
# Time:                        15:15:23   Distribution:                  chi2(3)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.0180     0.0009     20.382     0.0000      0.0163      0.0197
# x_lower        0.0019     0.0004     4.8122     0.0000      0.0011      0.0027
# x_upper        0.0036     0.0005     7.2477     0.0000      0.0026      0.0046
# z              0.0398     0.0013     31.603     0.0000      0.0373      0.0422
# ==============================================================================
# colon_cancer: subgroup
#                             OLS Estimation Summary
# ==============================================================================
# Dep. Variable:              indicator   R-squared:                      0.0412
# Estimator:                        OLS   Adj. R-squared:                 0.0412
# No. Observations:              128291   F-statistic:                    6725.0
# Date:                Mon, Aug 28 2023   P-value (F-stat)                0.0000
# Time:                        14:21:18   Distribution:                  chi2(3)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.0327     0.0019     17.510     0.0000      0.0290      0.0363
# x_lower        0.0039     0.0008     4.7241     0.0000      0.0023      0.0055
# x_upper       -0.0052     0.0011    -4.6660     0.0000     -0.0074     -0.0030
# z              0.1182     0.0028     41.789     0.0000      0.1127      0.1238
# ==============================================================================
# colon_cancer: baseline
#                             OLS Estimation Summary
# ==============================================================================
# Dep. Variable:              indicator   R-squared:                      0.0183
# Estimator:                        OLS   Adj. R-squared:                 0.0183
# No. Observations:              346191   F-statistic:                    7624.5
# Date:                Mon, Aug 28 2023   P-value (F-stat)                0.0000
# Time:                        14:21:15   Distribution:                  chi2(3)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.0268     0.0010     25.677     0.0000      0.0248      0.0289
# x_lower        0.0023     0.0005     4.8283     0.0000      0.0014      0.0032
# x_upper       -0.0016     0.0005    -2.9857     0.0028     -0.0027     -0.0006
# z              0.0621     0.0015     42.507     0.0000      0.0592      0.0649
# ==============================================================================
# diabetes: subgroup
#                             OLS Estimation Summary
# ==============================================================================
# Dep. Variable:              indicator   R-squared:                      0.0891
# Estimator:                        OLS   Adj. R-squared:                 0.0890
# No. Observations:              102848   F-statistic:                    8640.1
# Date:                Tue, Aug 29 2023   P-value (F-stat)                0.0000
# Time:                        22:49:42   Distribution:                  chi2(3)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.2625     0.0045     57.955     0.0000      0.2536      0.2714
# x_lower        0.4076     0.0185     21.982     0.0000      0.3713      0.4440
# x_upper        0.4769     0.0247     19.275     0.0000      0.4284      0.5253
# z              0.1192     0.0060     19.846     0.0000      0.1074      0.1309
# ==============================================================================
# diabetes: baseline
#                             OLS Estimation Summary
# ==============================================================================
# Dep. Variable:              indicator   R-squared:                      0.0703
# Estimator:                        OLS   Adj. R-squared:                 0.0703
# No. Observations:              133412   F-statistic:                    9126.7
# Date:                Tue, Aug 29 2023   P-value (F-stat)                0.0000
# Time:                        22:49:40   Distribution:                  chi2(3)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.2976     0.0042     70.720     0.0000      0.2893      0.3058
# x_lower        0.4215     0.0174     24.231     0.0000      0.3874      0.4556
# x_upper        0.4403     0.0213     20.714     0.0000      0.3986      0.4819
# z              0.0933     0.0054     17.183     0.0000      0.0827      0.1040
# ==============================================================================

# %%
dm_bl = subgroups_dict['diabetes']['baseline']['llr_results']
dm_sub = subgroups_dict['diabetes']['subgroup']['llr_results']

# %%
cc_bl = subgroups_dict['colon_cancer']['baseline']['llr_results']
cc_sub = subgroups_dict['colon_cancer']['subgroup']['llr_results']

# %%
bc_bl = subgroups_dict['breast_cancer']['baseline']['llr_results']
bc_sub = subgroups_dict['breast_cancer']['subgroup']['llr_results']

# %%
ttest_ind_from_stats(dm_sub.params['z'], dm_sub.std_errors['z'], dm_sub.nobs,
                     dm_bl.params['z'], dm_bl.std_errors['z'], dm_bl.nobs,
                     equal_var=False)
# Out:
# Ttest_indResult(statistic=1081.2459066857416, pvalue=0.0)

# %%
ttest_ind_from_stats(cc_sub.params['z'], cc_sub.std_errors['z'], cc_sub.nobs,
                     cc_bl.params['z'], cc_bl.std_errors['z'], cc_bl.nobs,
                     equal_var=False)
# Out:
# Ttest_indResult(statistic=6781.623908851374, pvalue=0.0)

# %%
ttest_ind_from_stats(bc_sub.params['z'], bc_sub.std_errors['z'], bc_sub.nobs,
                     bc_bl.params['z'], bc_bl.std_errors['z'], bc_bl.nobs,
                     equal_var=False)
# Out:
# Ttest_indResult(statistic=6745.966181667879, pvalue=0.0)
